# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
from pyspark import SparkContext

spark = SparkSession.builder \
    .appName("PageRank Assignment") \
    .master("local[*]") \
    .getOrCreate()

sc = spark.sparkContext

print("Spark Ready")
# Out:
# Spark Ready

# %%
file_path = r".\Assignment 4- datasets\Q2- webSearch\webpages\actions.txt"

lines = sc.textFile(file_path)

print("Total lines:", lines.count())
print(lines.take(5))
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperationException             Traceback (most recent call last)
# Cell In[3], line 3
#       1 file_path = r".\Assignment 4- datasets\Q2- webSearch\webpages\actions.txt"
#       2
# ----> 3 lines = sc.textFile(file_path)
#       4
#       5 print("Total lines:", lines.count())
#       6 print(lines.take(5))
#
# File d:\PGDDE\Mtech\Big data and ML\Assignment 4\a4env\Lib\site-packages\pyspark\core\context.py:1039, in SparkContext.textFile(self, name, minPartitions, use_unicode)
#     980 """
#     981 Read a text file from HDFS, a local file system (available on all
#     982 nodes), or any Hadoop-supported file system URI, and return it as an
#    (...)   1036 ['aa', 'bb', 'cc', 'x', 'y', 'z']
#    1037 """
#    1038 minPartitions = minPartitions or min(self.defaultParallelism, 2)
# -> 1039 return RDD(self._jsc.textFile(name, minPartitions), self, UTF8Deserializer(use_unicode))
#
# File d:\PGDDE\Mtech\Big data and ML\Assignment 4\a4env\Lib\site-packages\py4j\java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File d:\PGDDE\Mtech\Big data and ML\Assignment 4\a4env\Lib\site-packages\pyspark\errors\exceptions\captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# UnsupportedOperationException: getSubject is supported only if a security manager is allowed
